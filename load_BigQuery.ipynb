# %% [markdown]
# <a href="https://colab.research.google.com/github/96msnbykym/git-sample-yokoyama/blob/main/load_BigQuery.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Google Cloud SDKの構成を初期化
#プロジェクトIDを選択
# !gcloud init

# %%
from google.cloud import bigquery
from google.colab import files
from google.oauth2 import service_account

#ファイルをアップロード
uploaded = files.upload()
# アップロードしたJSONファイルのファイル名を指定
key_path = "hypnotic-guard-380905-4d6d5f5cb89c.json"

# 認証情報を設定
credentials = service_account.Credentials.from_service_account_file(key_path)
project_id = '{hypnotic-guard-380905}'

# BigQueryクライアントを作成
client = bigquery.Client(credentials=credentials, project=credentials.project_id)
# Out:
#      <input type="file" id="files-50ea8793-9a5b-4c6c-b3c1-1384fbbcf8c4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-50ea8793-9a5b-4c6c-b3c1-1384fbbcf8c4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# 実行するクエリ
query =  """
　　　　　　　　　　　　　　　　　　　　　　SELECT * FROM 
　　　　　　　　　　　　　　　　　　　　　`hypnotic-guard-380905.3_21.text` 
　　　　　　　　　　　　　　　　　　　　　　　LIMIT 1000
　             ;
         　　"""
# メソッドに`to_dataframe()`をつけるとpd.DataFrameで結果を受け取れる
df = client.query(query).to_dataframe()
df
# Out:
#                                         string_field_0
# 0    ['みんな', '匿名', '質問', '募集中', '質問', '答える', '遠い', ...
# 1    ['中森明菜', '藤井風', 'LiSA', 'ちゃん', '聴く', 'ジョングク', ...
# 2    ['今日', 'おさる', 'さん', 'ギター', '教室', '動画', '藤井風', ...
# 3    ['さん', '向ける', '発信', 'ホントだよ', 'ハート', 'さん', '藤井風...
# 4    ['今日', '藤井', '晴れ', '太陽', '肌寒い', '手袋', 'マフラー', ...
# ..                                                 ...
# 995  ['藤井風', 'はまる', '方', 'アーティスト', '推す', '活', '異なる'...
# 996  ['音楽祭', 'TM NETWORK', 'UNICORN', '電気グルーヴ', 'ac...
# 997         ['LIVE', '行う', '藤井風', 'スタイル', '好き', 'WWW']
# 998         ['Netflix', '藤井風', 'さん', '見る', '優しい', 'ん']
# 999                ['ω', '藤井', '風', '深田萌絵', 'ジャーナリスト']
#
# [1000 rows x 1 columns]
